# %% [markdown]
# # 中文多模态 VQA Demo
#
# 本 Notebook 演示如何调用工程中的推理接口，对单张图片和中文问题进行预测。

# %%
from src.inference.predict import predict_single
from PIL import Image

# TODO: 将下面路径替换为本地图片路径
image_path = "path/to/your/image.png"
question = "这张图里主要内容是什么？"

img = Image.open(image_path)
result = predict_single(img, question)
result
